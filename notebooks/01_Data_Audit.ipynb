# %%
import pandas as pd
import numpy as np

pd.set_option(
    "display.max_columns",
    None
)

# %%
incidents = pd.read_csv(
    "../data/incidents.csv"
)

airlines = pd.read_csv(
    "../data/airlines.csv"
)

aircraft = pd.read_csv(
    "../data/aircraft_types.csv"
)

routes = pd.read_csv(
    "../data/routes.csv"
)

trends = pd.read_csv(
    "../data/safety_trends.csv"
)

# %%
print(
    incidents.shape
)

print(
    airlines.shape
)

print(
    aircraft.shape
)

print(
    routes.shape
)

print(
    trends.shape
)
# Out:
# (25000, 29)
# (113, 16)
# (79, 16)
# (5000, 17)
# (55, 16)

# %%
incidents.head()
# Out:
#   incident_id        date  year  month            airline airline_region  \
# 0    AV000001  2002-02-27  2002      2      Kenya Airways         Africa
# 1    AV000002  1985-01-18  1985      1   TAP Air Portugal         Europe
# 2    AV000003  2008-08-23  2008      8  American Airlines   NorthAmerica
# 3    AV000004  1997-12-28  1997     12      ASKY Airlines         Africa
# 4    AV000005  1973-08-05  1973      8         Air France         Europe
#
#   airline_country         aircraft_type aircraft_category  manufacturer  \
# 0           Kenya  HAVILLAND Twin Otter         Turboprop  De Havilland
# 1        Portugal      Boeing 777-300ER          Widebody        Boeing
# 2             USA        Boeing 767-400          Widebody        Boeing
# 3            Togo            Fokker 100          Regional        Fokker
# 4          France            Boeing 720        Narrowbody        Boeing
#
#    aircraft_age_years  manufacture_year departure_airport arrival_airport  \
# ...

# %%
incidents.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   incident_id           25000 non-null  str
#  1   date                  25000 non-null  str
#  2   year                  25000 non-null  int64
#  3   month                 25000 non-null  int64
#  4   airline               25000 non-null  str
#  5   airline_region        25000 non-null  str
#  6   airline_country       25000 non-null  str
#  7   aircraft_type         25000 non-null  str
#  8   aircraft_category     25000 non-null  str
#  9   manufacturer          25000 non-null  str
#  10  aircraft_age_years    25000 non-null  int64
#  11  manufacture_year      25000 non-null  int64
#  12  departure_airport     25000 non-null  str
#  13  arrival_airport       25000 non-null  str
#  14  country               25000 non-null  str
#  15  region                25000 non-null  str
# ...

# %%
incidents.describe(
    include="all"
)
# Out:
#        incident_id        date         year         month        airline  \
# count        25000       25000  25000.00000  25000.000000          25000
# unique       25000       12870          NaN           NaN            112
# top       AV000001  1974-11-10          NaN           NaN  Ural Airlines
# freq             1           8          NaN           NaN            426
# mean           NaN         NaN   1990.21160      6.486240            NaN
# std            NaN         NaN     14.29522      3.450236            NaN
# min            NaN         NaN   1970.00000      1.000000            NaN
# 25%            NaN         NaN   1978.00000      3.000000            NaN
# 50%            NaN         NaN   1988.00000      6.000000            NaN
# 75%            NaN         NaN   2000.00000      9.000000            NaN
# max            NaN         NaN   2024.00000     12.000000            NaN
#
#        airline_region airline_country aircraft_type aircraft_category  \
# ...

# %%
incidents.isnull().sum()
# Out:
# incident_id                0
# date                       0
# year                       0
# month                      0
# airline                    0
# airline_region             0
# airline_country            0
# aircraft_type              0
# aircraft_category          0
# manufacturer               0
# aircraft_age_years         0
# manufacture_year           0
# departure_airport          0
# arrival_airport            0
# country                    0
# region                     0
# incident_type              0
# phase_of_flight            0
# weather_conditions         0
# primary_cause              0
# is_fatal                   0
# fatalities                 0
# occupants_onboard          0
# injuries                   0
# hull_loss                  0
# damage_category         1612
# investigation_status       0
# engines                    0
# seats_config               0
# dtype: int64
