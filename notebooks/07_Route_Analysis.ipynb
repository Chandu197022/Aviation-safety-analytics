# %%
import pandas as pd

# %%
routes = pd.read_csv(
    "../data/routes.csv"
)

routes.head()
# Out:
#   route_id departure_airport arrival_airport departure_country  \
# 0  RT00001              HKJK            URSS             Kenya
# 1  RT00002              CYVR            UUEE            Canada
# 2  RT00003              VVTS            SCVD           Vietnam
# 3  RT00004              SBSV            HTKJ            Brazil
# 4  RT00005              HTKJ            KJFK          Tanzania
#
#   arrival_country departure_region arrival_region  is_international  \
# 0          Russia           Africa         Europe                 1
# 1          Russia     NorthAmerica         Europe                 1
# 2           Chile      AsiaPacific   LatinAmerica                 1
# 3        Tanzania     LatinAmerica         Africa                 1
# 4             USA           Africa   NorthAmerica                 1
#
#    distance_km  avg_flight_time_h  annual_flights_2023  \
# 0          959                1.1                  565
# 1         1570                1.8                 5362
# ...

# %%
routes.sort_values(
    "risk_index",
    ascending=False
).head(20)
# Out:
#      route_id departure_airport arrival_airport departure_country  \
# 886   RT00887              VVDN            VOMM           Vietnam
# 4974  RT04975              CYYC            KATL            Canada
# 1683  RT01684              KORD            VNKT               USA
# 966   RT00967              LFLL            FNHU            France
# 3414  RT03415              VIDP            SKCL             India
# 800   RT00801              SCEL            OPLA             Chile
# 2204  RT02205              SKMR            VNPK          Colombia
# 2289  RT02290              HTKJ            KLAX          Tanzania
# 4936  RT04937              UUEE            SCEL            Russia
# 4965  RT04966              HKMO            HTDA             Kenya
# 329   RT00330              SAME            EDDH         Argentina
# 580   RT00581              DNMM            OTHH           Nigeria
# 4636  RT04637              RKSS            VOBL        SouthKorea
# ...

# %%
routes.sort_values(
    "risk_index",
    ascending=False
).head(20)
# Out:
#      route_id departure_airport arrival_airport departure_country  \
# 886   RT00887              VVDN            VOMM           Vietnam
# 4974  RT04975              CYYC            KATL            Canada
# 1683  RT01684              KORD            VNKT               USA
# 966   RT00967              LFLL            FNHU            France
# 3414  RT03415              VIDP            SKCL             India
# 800   RT00801              SCEL            OPLA             Chile
# 2204  RT02205              SKMR            VNPK          Colombia
# 2289  RT02290              HTKJ            KLAX          Tanzania
# 4936  RT04937              UUEE            SCEL            Russia
# 4965  RT04966              HKMO            HTDA             Kenya
# 329   RT00330              SAME            EDDH         Argentina
# 580   RT00581              DNMM            OTHH           Nigeria
# 4636  RT04637              RKSS            VOBL        SouthKorea
# ...

# %%
routes.sort_values(
    "distance_km",
    ascending=False
).head(20)
# Out:
#      route_id departure_airport arrival_airport departure_country  \
# 4116  RT04117              VECC            SCEL             India
# 3067  RT03068              SCVD            CYYC             Chile
# 1263  RT01264              EDDB            VVTS           Germany
# 3327  RT03328              OERK            MMGL      Saudi Arabia
# 856   RT00857              ZSPD            URSS             China
# 1165  RT01166              ZUUU            EGGD             China
# 4771  RT04772              MMMX            OICC            Mexico
# 862   RT00863              ZHHH            MMGL             China
# 2003  RT02004              SBCF            WSSS            Brazil
# 4992  RT04993              WARR            LFLL         Indonesia
# 4612  RT04613              LFPG            OPLA            France
# 735   RT00736              OEJN            SAEZ      Saudi Arabia
# 1136  RT01137              CYMX            MMMX            Canada
# ...
