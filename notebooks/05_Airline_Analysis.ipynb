# %%
import sys
import os

sys.path.append(
    os.path.abspath("..")
)

# %%
from src.airline_analysis import AirlineAnalysis

# %%
import pandas as pd

df = pd.read_csv(
    "../data/incidents.csv"
)

df.head()
# Out:
#   incident_id        date  year  month            airline airline_region  \
# 0    AV000001  2002-02-27  2002      2      Kenya Airways         Africa
# 1    AV000002  1985-01-18  1985      1   TAP Air Portugal         Europe
# 2    AV000003  2008-08-23  2008      8  American Airlines   NorthAmerica
# 3    AV000004  1997-12-28  1997     12      ASKY Airlines         Africa
# 4    AV000005  1973-08-05  1973      8         Air France         Europe
#
#   airline_country         aircraft_type aircraft_category  manufacturer  ...  \
# 0           Kenya  HAVILLAND Twin Otter         Turboprop  De Havilland  ...
# 1        Portugal      Boeing 777-300ER          Widebody        Boeing  ...
# 2             USA        Boeing 767-400          Widebody        Boeing  ...
# 3            Togo            Fokker 100          Regional        Fokker  ...
# 4          France            Boeing 720        Narrowbody        Boeing  ...
#
# ...

# %%
AirlineAnalysis.airline_incidents(
    df
)
# Out:
#                    airline  incident_count
# 103          Ural Airlines             426
# 77             S7 Airlines             253
# 60                Lion Air             251
# 74        Rossiya Airlines             250
# 37                  Cubana             248
# ..                     ...             ...
# 73           Qatar Airways             196
# 80   Scandinavian Airlines             193
# 98            Thai Airways             191
# 109               Wizz Air             190
# 44               Eurowings             185
#
# [112 rows x 2 columns]

# %%
AirlineAnalysis.airline_fatalities(
    df
)
# Out:
#                    airline  fatalities
# 103          Ural Airlines        7151
# 97                   Tarom        5103
# 67         Olympic Airways        5050
# 14               Air Koryo        4885
# 37                  Cubana        4832
# ..                     ...         ...
# 80   Scandinavian Airlines        1674
# 38         Delta Air Lines        1592
# 73           Qatar Airways        1589
# 72                  Qantas        1472
# 27         British Airways        1192
#
# [112 rows x 2 columns]
